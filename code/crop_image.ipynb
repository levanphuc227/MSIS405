# %%
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path

import cv2

# %%
DIRECTORY = os.path.join(Path(os.getcwd()).parent,'dataset')
CATEGORIES=os.listdir(DIRECTORY)
SAVEIMG=os.path.join(DIRECTORY,CATEGORIES[0])

# %%
print(DIRECTORY)
print(CATEGORIES)
print(SAVEIMG)
# Out:
# C:\Users\admin\Documents\MSIS405\dataset
# ['unknow', 'without_mask', 'with_mask']
# C:\Users\admin\Documents\MSIS405\dataset\unknow

# %%
all_files = os.listdir(SAVEIMG)

for f in all_files:
    os.remove(os.path.join(SAVEIMG,f))

print(os.listdir(SAVEIMG))
# Out:
# []

# %%
filename = os.path.join(DIRECTORY,CATEGORIES[1],'0_0_sunhonglei_0125.jpg')

# %%
#img=cv2.imread(filename)
#plt.imshow(img)
#plt.show()

# %%
#height, width, channels=img.shape

# %%
#print(height, width, channels)

# %%
#print(img[30:height-1][20:width-1][channels-1]

# %%
def cropImg(img,filename):
    height, width, channels=img.shape
    cropped_image = img[0:int(height*2/3), int(width*1/3):width-1]
    plt.imshow(cropped_image)
    cv2.imwrite(os.path.join(SAVEIMG,filename), cropped_image)

# %%
for category in CATEGORIES:
    path = os.path.join(DIRECTORY, category)
    for filename in os.listdir(path):
        img_path = os.path.join(path, filename)
        img=cv2.imread(img_path)
        print(img_path)
        cropImg(img,filename)
# Out:
# C:\Users\admin\Documents\MSIS405\dataset\without_mask\0.jpg
# C:\Users\admin\Documents\MSIS405\dataset\without_mask\0_0_aidai_0014.jpg
# C:\Users\admin\Documents\MSIS405\dataset\without_mask\0_0_aidai_0029.jpg
# C:\Users\admin\Documents\MSIS405\dataset\without_mask\0_0_aidai_0043.jpg
# C:\Users\admin\Documents\MSIS405\dataset\without_mask\0_0_aidai_0074.jpg
# C:\Users\admin\Documents\MSIS405\dataset\without_mask\0_0_aidai_0084.jpg
# C:\Users\admin\Documents\MSIS405\dataset\without_mask\0_0_aidai_0136.jpg
# C:\Users\admin\Documents\MSIS405\dataset\without_mask\0_0_anhu_0004.jpg
# C:\Users\admin\Documents\MSIS405\dataset\without_mask\0_0_anhu_0020.jpg
# C:\Users\admin\Documents\MSIS405\dataset\without_mask\0_0_anhu_0025.jpg
# C:\Users\admin\Documents\MSIS405\dataset\without_mask\0_0_anhu_0027.jpg
# C:\Users\admin\Documents\MSIS405\dataset\without_mask\0_0_anhu_0056.jpg
# C:\Users\admin\Documents\MSIS405\dataset\without_mask\0_0_anhu_0057.jpg
# ...
